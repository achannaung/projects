# %% [markdown]
# <center><h1 style='font-family:Brush script MT;font-size:40px;color:red'>Myanmar Township Pcode</h1>

# %% [markdown]
# ## Data Processing

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('MM_Pcode.csv')
df.head(2)
# Out:
#            SR District Township                  Village_T         Village  \
# 0  Ayeyarwady   Pyapon   Bogale  (Kyun Nyo Gyi) Kyun Hteik  Da None Chaung
# 1  Ayeyarwady   Pyapon   Bogale  (Kyun Nyo Gyi) Kyun Hteik    Hteik Chaung
#
#      Village_MM Commonly_Used_Local_Vlg_Name_Eng  \
# 0  ဓနုံးချောင်း                              NaN
# 1   ထိပ်ချောင်း                              NaN
#
#   Commonly_Used_Local_Vlg_Name_Mya   Latitude  Longitude
# 0                              NaN  16.189430  95.360931
# 1                              NaN  16.139151  95.317284

# %%
ndf = df[['SR','Township', 'Village', 'Village_MM']]

# %%
ndf.shape
# Out:
# (72263, 4)

# %%
sdf = df[['SR', 'District', 'Township']]
#sdf.head(2)

# %%
#ndf[ndf['Township']== input("Township : ")].sort_values(by='Village_MM')

# %%
#ndf.loc[ndf['Township'].str.contains(input("Township Name: "))].sort_values(by='Village_MM')

# %% [markdown]
# ## Number of Townships by State/Region

# %%
print("Number of Magway Township: ", mgy_tsp['SR'].count())
print("Number of Sagaing Township: ", sgg_tsp['SR'].count())
print("Number of Chin Township: ", chn_tsp['SR'].count())
print("Number of Rakhine Township: ", rkh_tsp['SR'].count())
print("Number of YGN Township: ", ygn_dist['SR'].count())
print("Number of MDY Township: ", mdy_dist['SR'].count())
print("Number of NPT Township: ", npt['SR'].count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 print("Number of Magway Township: ", mgy_tsp['SR'].count())
#       2 print("Number of Sagaing Township: ", sgg_tsp['SR'].count())
#       3 print("Number of Chin Township: ", chn_tsp['SR'].count())
#
# NameError: name 'mgy_tsp' is not defined

# %% [markdown]
# ## Number of Villages by State/Region

# %%
print("Number of Villages in Magway Region:", mgy)
print("Number of Villages in Sagaing Region:", sgg)
print("Number of Villages in Chin State:", chin)
print("Number of Villages in Rakhine State:", rkh)
print("Number of Villages in Yangon Region:", ygn)
print("Number of Villages in Mandalay Region:", mdy_v)
print("Number of Villages in Nay Pyi Taw:", npt_v)

# %% [markdown]
# ## Data Dictionary

# %%
#mgy_tsp
#sgg_tsp
#chn_tsp
#rkh_tsp
#mdy_dist
#ygn_dist
#npt

# %% [markdown]
# <center><h2 style='font-family:Tahoma;font-size:22px;color:crimson'>Filter State/Region & Township</h2>

# %% [markdown]
# <h3 style='color:indigo'>Filter by State/Region </h3>

# %%
#sdf.loc[sdf['SR'].str.contains(input("State/Region Name:"))].sort_values(by='Township').drop_duplicates()

# %% [markdown]
# <h3 style='color:indigo'>Filter by Township </h3>

# %%
ndf[ndf['Township'].str.contains(input("Township Name: "))].sort_values(by='Village_MM')
# Out:
# Township Name:  Sag
#             SR Township                    Village          Village_MM
# 47780  Sagaing  Sagaing                        Kin                ကင်း
# 47718  Sagaing  Sagaing                        Kin                ကင်း
# 47712  Sagaing  Sagaing                    Kin Taw            ကင်းတော်
# 47852  Sagaing  Sagaing                Kan Nar Taw          ကန္နားတော်
# 47773  Sagaing  Sagaing                   Kan Kone            ကန်ကုန်း
# 47714  Sagaing  Sagaing               Kan Gyi Kone        ကန်ကြီးကုန်း
# 47864  Sagaing  Sagaing                Kan Taw Yoe         ကန်တော်ရိုး
# 47707  Sagaing  Sagaing                Ka Thea Tar               ကသဲတာ
# 47711  Sagaing  Sagaing                 Kaing Pyin          ကိုင်းပြင်
# 47727  Sagaing  Sagaing                       Kone               ကုန်း
# 47827  Sagaing  Sagaing                       Kone               ကုန်း
# 47688  Sagaing  Sagaing                   Kone Gyi           ကုန်းကြီး
# ...
